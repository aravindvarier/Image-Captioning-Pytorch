# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
df = pd.read_csv('rnnTest.csv')
df = df[df['experiment'].str.contains("smoothing")]
df.tail()
# Out:
#                                   experiment  epoch        loss  \
# 19   resnet50_h1024_bs32_ft1_aap1_smoothing0      6  187.210952
# 20   resnet101_h256_bs64_ft0_aap1_smoothing0     21  182.712203
# 21  resnet101_h1024_bs32_ft1_aap1_smoothing0      6  186.546437
# 22   resnet50_h1024_bs32_ft0_aap1_smoothing0      6  190.426664
# 23  resnet101_h1024_bs32_ft0_aap1_smoothing0     12  185.054270
#
#                           date    Bleu_1    Bleu_2    Bleu_3    Bleu_4  \
# 19  2020-04-15 08:37:29.503812  0.629851  0.452654  0.319037  0.220403
# 20  2020-04-15 08:39:20.754660  0.605066  0.424247  0.292809  0.199179
# 21  2020-04-15 11:53:01.354201  0.629993  0.454123  0.318587  0.219859
# 22  2020-04-15 12:14:54.934210  0.606817  0.429772  0.299579  0.207970
# 23  2020-04-15 16:00:34.066662  0.607285  0.427718  0.296295  0.202497
#
#       METEOR   ROUGE_L     CIDEr
# 19  0.213617  0.475624  0.554527
# 20  0.206026  0.460299  0.535180
# 21  0.219206  0.480520  0.586416
# 22  0.206227  0.459006  0.518767
# 23  0.209933  0.462595  0.523922

# %%
exp_idx_to_label = {
  0: 'encoder',
  1: 'lstm_hidden_units',
  2: 'batch_size',
  3: 'fine_tune'
}

for index, row in df.iterrows():
  for exp_idx, item in enumerate(row['experiment'].split('_')):
    if exp_idx in exp_idx_to_label:
      item = int(re.sub("[^0-9]", "", item)) if exp_idx != 0 else item
      df.at[index, exp_idx_to_label[exp_idx]] = item
      
df.tail()
# Out:
#                                   experiment  epoch        loss  \
# 19   resnet50_h1024_bs32_ft1_aap1_smoothing0      6  187.210952
# 20   resnet101_h256_bs64_ft0_aap1_smoothing0     21  182.712203
# 21  resnet101_h1024_bs32_ft1_aap1_smoothing0      6  186.546437
# 22   resnet50_h1024_bs32_ft0_aap1_smoothing0      6  190.426664
# 23  resnet101_h1024_bs32_ft0_aap1_smoothing0     12  185.054270
#
#                           date    Bleu_1    Bleu_2    Bleu_3    Bleu_4  \
# 19  2020-04-15 08:37:29.503812  0.629851  0.452654  0.319037  0.220403
# 20  2020-04-15 08:39:20.754660  0.605066  0.424247  0.292809  0.199179
# 21  2020-04-15 11:53:01.354201  0.629993  0.454123  0.318587  0.219859
# 22  2020-04-15 12:14:54.934210  0.606817  0.429772  0.299579  0.207970
# 23  2020-04-15 16:00:34.066662  0.607285  0.427718  0.296295  0.202497
#
#       METEOR   ROUGE_L     CIDEr    encoder  lstm_hidden_units  batch_size  \
# 19  0.213617  0.475624  0.554527   resnet50             1024.0        32.0
# 20  0.206026  0.460299  0.535180  resnet101              256.0        64.0
# 21  0.219206  0.480520  0.586416  resnet101             1024.0        32.0
# 22  0.206227  0.459006  0.518767   resnet50             1024.0        32.0
# 23  0.209933  0.462595  0.523922  resnet101             1024.0        32.0
#
#     fine_tune
# 19        1.0
# 20        0.0
# 21        1.0
# 22        0.0
# 23        0.0

# %%
perf_metrics = ['Bleu_1', 'Bleu_2', 'Bleu_3', 'Bleu_4', 'METEOR', 'ROUGE_L', 'CIDEr']

# %% [markdown]
# ## Experiment 1: Effect of improved image feature quality

# %%
img_quality_df = df[(df['lstm_hidden_units'] == 512) & (df['fine_tune'] == 0)]
img_quality_df = img_quality_df.drop(['date', 'experiment', 'epoch', 'loss', 'fine_tune'], axis = 1) 
img_quality_df = img_quality_df.set_index('encoder')
img_quality_df
# Out:
#              Bleu_1    Bleu_2    Bleu_3    Bleu_4    METEOR   ROUGE_L  \
# encoder
# resnet18   0.585697  0.403666  0.273895  0.183250  0.199891  0.449368
# resnet50   0.599512  0.423429  0.292556  0.200647  0.207904  0.456299
# resnet101  0.607266  0.430646  0.295453  0.201697  0.204555  0.460997
#
#               CIDEr  lstm_hidden_units  batch_size
# encoder
# resnet18   0.477106              512.0        64.0
# resnet50   0.526517              512.0        64.0
# resnet101  0.510145              512.0        64.0

# %%
ax = img_quality_df[['Bleu_4', 'METEOR', 'ROUGE_L', 'CIDEr']].plot(style=['+-','o-','.--','s:'])
ax.set_ylabel("scores")
ax.set_title("Effect of improved image feature extraction on scores")
# Out:
# Text(0.5, 1.0, 'Effect of improved image feature extraction on scores')

# %% [markdown]
# ## Experiment 2: Effect of fine-tuning the encoders

# %%
img_quality_df = df[(df['lstm_hidden_units'] == 512)]
print(img_quality_df.shape)
img_quality_df = img_quality_df.drop(['date', 'experiment', 'epoch', 'loss'], axis = 1) 
img_quality_df = img_quality_df.sort_values(by=['encoder', 'fine_tune'])

img_quality_df
# Out:
# (6, 15)
#       Bleu_1    Bleu_2    Bleu_3    Bleu_4    METEOR   ROUGE_L     CIDEr  \
# 12  0.607266  0.430646  0.295453  0.201697  0.204555  0.460997  0.510145
# 11  0.628727  0.451323  0.314709  0.214663  0.215835  0.481537  0.574750
# 8   0.585697  0.403666  0.273895  0.183250  0.199891  0.449368  0.477106
# 14  0.605223  0.423746  0.292273  0.200727  0.201403  0.457477  0.495662
# 10  0.599512  0.423429  0.292556  0.200647  0.207904  0.456299  0.526517
# 9   0.626872  0.450860  0.318633  0.221193  0.214221  0.478060  0.551322
#
#       encoder  lstm_hidden_units  batch_size  fine_tune
# 12  resnet101              512.0        64.0        0.0
# 11  resnet101              512.0        64.0        1.0
# 8    resnet18              512.0        64.0        0.0
# 14   resnet18              512.0        64.0        1.0
# 10   resnet50              512.0        64.0        0.0
# 9    resnet50              512.0        64.0        1.0

# %% [markdown]
# ### Plot the difference between fine tuing and without fine tuning

# %%
# img_quality_df = img_quality_df.set_index('encoder')
finetuned_diff_df = img_quality_df.set_index(['encoder']).groupby('encoder').diff()

finetuned_diff_df = finetuned_diff_df.dropna()
finetuned_diff_df = finetuned_diff_df.reindex(["resnet18", "resnet50", "resnet101"])
finetuned_diff_df
# Out:
#              Bleu_1    Bleu_2    Bleu_3    Bleu_4    METEOR   ROUGE_L  \
# encoder
# resnet18   0.019526  0.020080  0.018378  0.017477  0.001512  0.008109
# resnet50   0.027361  0.027431  0.026077  0.020546  0.006318  0.021762
# resnet101  0.021460  0.020677  0.019256  0.012966  0.011280  0.020541
#
#               CIDEr  lstm_hidden_units  batch_size  fine_tune
# encoder
# resnet18   0.018556                0.0         0.0        1.0
# resnet50   0.024805                0.0         0.0        1.0
# resnet101  0.064605                0.0         0.0        1.0

# %%
ax = finetuned_diff_df[['Bleu_4', 'METEOR', 'ROUGE_L', 'CIDEr']].plot(style=['+-','o-','.--','s:'])
ax.set_ylabel("scores")
ax.set_title("Difference of scores with and without fine-tuning")
# Out:
# Text(0.5, 1.0, 'Difference of scores with and without fine-tuning')

# %% [markdown]
# ## Experiment 3: Effect of varying LSTM dimension size

# %%
from IPython.display import display, HTML

for encoder in ["resnet18", "resnet50", "resnet101"]:
  decoder_dim_df = df[(df['fine_tune'] == 0) & (df['encoder'] == encoder)] \
    .sort_values(by=['lstm_hidden_units']) \
    .drop(['date', 'experiment', 'epoch', 'loss', 'fine_tune', 'batch_size', 'encoder'], axis = 1) \
    .set_index('lstm_hidden_units')

  print("==================================================")
  print("Encoder Type used: ", encoder)
#   print(decoder_dim_df)
  display(HTML(decoder_dim_df.to_html()))
  
  ax = decoder_dim_df[['Bleu_4', 'METEOR', 'ROUGE_L', 'CIDEr']].plot(style=['+-','o-','.--','s:'])
  ax.set_ylabel("scores")
  ax.set_title("Effect of varying LSTM hidden dimension size using " + encoder)
  plt.show()
# Out:
# ==================================================
# Encoder Type used:  resnet18
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bleu_1</th>
#       <th>Bleu_2</th>
#       <th>Bleu_3</th>
#       <th>Bleu_4</th>
#       <th>METEOR</th>
#       <th>ROUGE_L</th>
#       <th>CIDEr</th>
#     </tr>
#     <tr>
#       <th>lstm_hidden_units</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>256.0</th>
#       <td>0.589039</td>
#       <td>0.410389</td>
#       <td>0.280721</td>
#       <td>0.19040</td>
#       <td>0.199288</td>
#       <td>0.448396</td>
#       <td>0.483093</td>
#     </tr>
#     <tr>
#       <th>512.0</th>
#       <td>0.585697</td>
#       <td>0.403666</td>
#       <td>0.273895</td>
#       <td>0.18325</td>
#       <td>0.199891</td>
#       <td>0.449368</td>
#       <td>0.477106</td>
#     </tr>
#     <tr>
#       <th>1024.0</th>
#       <td>0.597467</td>
#       <td>0.414628</td>
#       <td>0.283716</td>
#       <td>0.19290</td>
#       <td>0.203435</td>
#       <td>0.453616</td>
#       <td>0.495308</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Encoder Type used:  resnet50
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bleu_1</th>
#       <th>Bleu_2</th>
#       <th>Bleu_3</th>
#       <th>Bleu_4</th>
#       <th>METEOR</th>
#       <th>ROUGE_L</th>
#       <th>CIDEr</th>
#     </tr>
#     <tr>
#       <th>lstm_hidden_units</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>256.0</th>
#       <td>0.600070</td>
#       <td>0.423325</td>
#       <td>0.290799</td>
#       <td>0.197875</td>
#       <td>0.207608</td>
#       <td>0.458321</td>
#       <td>0.527571</td>
#     </tr>
#     <tr>
#       <th>512.0</th>
#       <td>0.599512</td>
#       <td>0.423429</td>
#       <td>0.292556</td>
#       <td>0.200647</td>
#       <td>0.207904</td>
#       <td>0.456299</td>
#       <td>0.526517</td>
#     </tr>
#     <tr>
#       <th>1024.0</th>
#       <td>0.606817</td>
#       <td>0.429772</td>
#       <td>0.299579</td>
#       <td>0.207970</td>
#       <td>0.206227</td>
#       <td>0.459006</td>
#       <td>0.518767</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
# Encoder Type used:  resnet101
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bleu_1</th>
#       <th>Bleu_2</th>
#       <th>Bleu_3</th>
#       <th>Bleu_4</th>
#       <th>METEOR</th>
#       <th>ROUGE_L</th>
#       <th>CIDEr</th>
#     </tr>
#     <tr>
#       <th>lstm_hidden_units</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>256.0</th>
#       <td>0.605066</td>
#       <td>0.424247</td>
#       <td>0.292809</td>
#       <td>0.199179</td>
#       <td>0.206026</td>
#       <td>0.460299</td>
#       <td>0.535180</td>
#     </tr>
#     <tr>
#       <th>512.0</th>
#       <td>0.607266</td>
#       <td>0.430646</td>
#       <td>0.295453</td>
#       <td>0.201697</td>
#       <td>0.204555</td>
#       <td>0.460997</td>
#       <td>0.510145</td>
#     </tr>
#     <tr>
#       <th>1024.0</th>
#       <td>0.607285</td>
#       <td>0.427718</td>
#       <td>0.296295</td>
#       <td>0.202497</td>
#       <td>0.209933</td>
#       <td>0.462595</td>
#       <td>0.523922</td>
#     </tr>
#   </tbody>
# </table>
